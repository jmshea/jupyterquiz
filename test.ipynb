# %% [markdown]
# # Test and demonstration notebook for Javascript quiz tool
#
# This notebook tests and demonstrates the jupyterquiz library and its use. It draws from a set of example questions that show the supported capabilities of the jupyterquiz library.
#
# In particular, this notebook also serves to test different ways for the library to load questions:
# 1. **From a URL:** This is the preferred approach. It will embed a copy of the questions in your Jupyter notebook (and Jupyter book), but it will also try to load the latest version of the questions from the URL via Javascript at page load time. If the questions cannot be loaded from the URL, the stored versions will be used as a fallback.
# 2. **From a JSON File:** This may be more convenient for local testing.
# 3. **From a Python Dict:** This is probably the best path for testing new questions because they can be added and tested within a Jupyter notebook.
#
# jupyterquiz supports drawing a random subset of questions, and that is also tested.
#
# $$ \begin{bmatrix} 7 \end{bmatrix}$$

# %%
from jupyterquiz import display_quiz

git_path="https://raw.githubusercontent.com/jmshea/jupyterquiz/main/examples/"

# %% [markdown]
# ## Test all question types, standard URL loading method:
#
# $~$

# %%
display_quiz(git_path+"questions.json")
# Out:
# <div id="VzeEfCMQgLcM" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #VzeEfCMQgLcM {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %% [markdown]
# Using the 'fdsp' color scheme:

# %%
display_quiz(git_path+"questions.json", colors='fdsp')
# Out:
# <div id="zkBFsXOyDoCu" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #zkBFsXOyDoCu {
#    --jq-multiple-choice-bg: #345995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #e26d5a;
#    --jq-numeric-bg: #5bc0eb;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #861657;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #666666;
#    --jq-correct-color: #87a878;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;
#     col

# %% [markdown]
# # Test loading all questions from file and customizing individual colors:

# %%
display_quiz("examples/questions.json", 
            )
# Out:
# <div id="YWViAaJWBBGB" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #YWViAaJWBBGB {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %%
display_quiz("examples/questions.json", 
             colors={
               '--jq-many-choice-bg': '#224dea',
               '--jq-multiple-choice-bg': '#a45995'
             }
            )
# Out:
# <div id="VElEESdcmzsT" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #VElEESdcmzsT {
#    --jq-multiple-choice-bg: #a45995;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #224dea;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;
#     c

# %% [markdown]
# # Test loading questions from dict (this is for more rapid question generation and testing) and changing border radius for "flat" look:

# %%
import json
with open("examples/questions.json", "r") as file:
    questions=json.load(file)
    
display_quiz(questions,  border_radius=0)
# Out:
# <div id="hdKgcOsxlfXf" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 0px; text-align: left"><style>
# #hdKgcOsxlfXf {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %%
# #Leave this here for when doing question development

# import json
# with open("examples/questions.json", "w") as file:
#     json.dump(questions, file, indent=4)

# %% [markdown]
# ## Test sampling from questions:

# %%
display_quiz(git_path+"questions.json",2)
# Out:
# <div id="LuHUdZkUfLpq" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="2" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #LuHUdZkUfLpq {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;
#     color

# %%
github_preview=[questions[0]]+[questions[2]]

# %%
display_quiz(github_preview)
# Out:
# <div id="zLMRHDZFWbwh" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #zLMRHDZFWbwh {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %% [markdown]
# # Test custom border radius, question alignment, max_width

# %%
display_quiz(git_path+"questions.json", border_radius=0, question_alignment='center', max_width=1000)
# Out:
# <div id="jptNITLvvnbw" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="1000" style="border-radius: 0px; text-align: center"><style>
# #jptNITLvvnbw {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %% [markdown]
# # Test URL support

# %%
example_link = [{
        "question": "The variable mylist is a Python list. " + \
        "Choose which code snippet will append the item 3 to mylist. " +
        "See [W3Schools: Python Join Two Lists]" + \
        "(https://www.w3schools.com/python/gloss_python_join_lists.asp) for reference.",
        "type": "multiple_choice",
        "answers": [
            {
                "code": "mylist+=3",
                "correct": False
            },
            {
                "code": "mylist+=[3]",
                "correct": True
            },
            {
                "code": "mylist+={3}",
                "correct": False
            }
        ]
    }]

# %%
display_quiz(example_link)
# Out:
# <div id="TmximXanMpSV" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #TmximXanMpSV {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %% [markdown]
# # String Test

# %%
example_string = [{
        "question": "Who was the 35th president (1961-63) of the US?" ,
        "type": "string",
        "answers": [
            {
                "answer": "John F. Kennedy",
                "correct": True,
                "feedback": "Correct. John F. Kennedy was the 35th president of the U.S.",
                "match_case": False,
                "fuzzy_threshold": 0.78
            },
            {
                "answer": "JFK",
                "correct": True,
                "feedback": "Correct. John F. Kennedy was the 35 preside of the U.S."
            },
            {
                "answer": "Kennedy",
                "correct": False,
                "feedback": "Please also provide the first name.",
                "match_case": False
            }, 
        ]
    }]

# %%
display_quiz(example_string)
# Out:
# <div id="qYuBQCwAkKXy" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #qYuBQCwAkKXy {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed; /* Only difference from MCButton */
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;

# %% [markdown]
# # Drag and Drop Matching Test

# %%
example_drag_drop = [{
    "question": "Match the items:",
    "type": "drag_drop",
    "pairs": [
        {"label": "Label 1", "answer": "Answer 1"},
        {"label": "Label 2", "answer": "Answer 2"}
    ],
    "options": ["Answer 1", "Answer 2", "Distractor 1"]
}]

display_quiz(example_drag_drop)
# Out:
# <div id="IqniFoLhenid" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #IqniFoLhenid {
#    --jq-multiple-choice-bg: #392061;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-drag-drop-bg: #00305e;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
#    --jq-link-color: #9abafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode>pre {
#     padding: 4px;
# }
#
# .Quiz code {
#     background-color: lightgray;
#     color: black;
# }
#
# .Quiz .QuizCode code {
#     background-color: inherit;
#     color: inherit;
# }
#
#
# .Quiz .MCButton code {
#     background-color: inherit;
#     color: inherit;
# }
#
# .MCButton .QuizCode {
#     text-align: left;
# }
#
#
# .Quiz .JQLink {
#     color: var(--jq-link-color) !important;
#     text-decoration: underline;
# }
#
#
#
# .Answer {
#     border-radius: inherit;
#     display: grid;
#     grid-gap: 10px;
#     grid-template-columns: 1fr 1fr;
#     margin: 10px 0;
# }
#
# @media only screen and (max-width:480px) {
#     .Answer {
#         grid-template-columns: 1fr;
#     }
#
# }
#
# .Feedback {
#     font-size: 16pt;
#     text-align: center;
# /*    min-height: 2em;*/
# }
#
# .Input {
#     align: left;
#     font-size: 20pt;
# }
#
# .Input-text {
#     display: block;
#     margin: 10px;
#     color: inherit;
#     width: unset;
#     min-width: 140px;
#     max-width: 93%;
#     field-sizing: content;
#     background-color: var(--jq-numeric-input-bg);
#     color: var(--jq-text-color);
#     padding: 5px;
#     padding-left: 10px;
#     font-family: inherit;
#     font-size: 20px;
#     font-weight: inherit;
#     line-height: 20pt;
#     border: none;
#     border-radius: 0.2rem;
#     transition: box-shadow 0.1s);
# }
#
# .Input-text:focus {
#     /*outline: none;*/
#     background-color: var(--jq-numeric-input-bg);
#     box-shadow: 0.6rem 0.8rem 1.4rem -0.5rem var(--jq-numeric-input-shadow);
# }
#
# .MCButton {
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
#
# .MCButton p {
#     color: inherit;
# }
#
# .MultipleChoiceQn {
#     padding: 10px;
#     background: var(--jq-multiple-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .ManyChoiceQn {
#     padding: 10px;
#     background: var(--jq-many-choice-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .NumericQn {
#     background: var(--jq-numeric-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .NumericQn p {
#     color: inherit;
# }
#
# .StringQn {
#     background: var(--jq-string-bg);
#     border-radius: inherit;
#     color: var(--jq-text-color);
#     padding: 10px;
# }
#
# .StringQn p {
#     color: inherit;
# }
#
#
# .InpLabel {
#     color: var(--jq-numeric-input-label);
#     float: left;
#     font-size: 15pt;
#     line-height: 34px;
#     margin-right: 10px;
# }
#
# .incorrect {
#     color: var(--jq-incorrect-color);
# }
#
# .correct {
#     color: var(--jq-correct-color);
# }
#
# .correctButton {
#     /*
#     background: var(--jq-correct-color);
#    */
#     animation: correct-anim 0.6s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# .incorrectButton {
#     animation: incorrect-anim 0.8s ease;
#     animation-fill-mode: forwards;
#     box-shadow: inset 0 0 5px var(--jq-mc-button-inset-shadow);
#     color: var(--jq-text-color);
#     /*outline: none;*/
# }
#
# @keyframes incorrect-anim {
#     100% {
#         background-color: var(--jq-incorrect-color);
#     }
# }
#
# @keyframes correct-anim {
#     100% {
#         background-color: var(--jq-correct-color);
#     }
# }
#
# /* Drag and Drop Matching Question Styles */
#
# .DragDropQn {
#     padding: 10px;
#     background: var(--jq-drag-drop-bg);
#     color: var(--jq-text-color);
#     border-radius: inherit;
# }
#
# .DragDropQn p {
#     color: inherit;
# }
#
# /* Critical: Override the grid layout from .Answer */
# .DragDropQn .Answer,
# .DragDropAnswer {
#     display: block !important;
#     grid-template-columns: none !important;
#     grid-template-rows: none !important;
#     gap: 0 !important;
#     grid: none !important;
#     margin: 10px 0; /* Keep the margin from original .Answer */
# }
#
# .DragDropMainContainer {
#     display: block;
#     width: 100%;
# }
#
# .DragDropLabels {
#     margin-bottom: 20px;
#     width: 100%;
#     display: block;
#     clear: both;
# }
#
# .DragDropLabelRow {
#     display: flex;
#     align-items: center;
#     margin-bottom: 10px;
#     width: 100%;
#     box-sizing: border-box;
# }
#
# .DragDropLabel {
#     flex: 0 0 70%;
#     font-size: 16px;
#     padding: 10px; /* Match MCButton padding exactly */
#     background-color: rgba(255, 255, 255, 0.1);
#     border-radius: inherit;
#     min-height: 20px;
#     box-sizing: border-box;
#     color: inherit;
# }
#
# .DropZone {
#     /* Exact MCButton styling with drag-specific modifications */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-style: dashed;
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: pointer;
#     text-align: center;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific layout properties */
#     flex: 0 0 30%;
#     min-height: 40px;
#     transition: all 0.3s ease;
#     box-sizing: border-box;
# }
#
# .DropZone.dragover {
#     border-color: var(--jq-correct-color);
#     border-style: solid;
#     background-color: rgba(0, 145, 19, 0.1);
#     transform: scale(1.02);
# }
#
# .DropZone.filled {
#     border-style: solid;
#     background: var(--jq-mc-button-bg);
#     color: #333333;
# }
#
# .DropZone.correct {
#     border-color: var(--jq-correct-color);
#     background-color: rgba(0, 145, 19, 0.2);
#     color: var(--jq-correct-color);
# }
#
# .DropZone.incorrect {
#     border-color: var(--jq-incorrect-color);
#     background-color: rgba(200, 2, 2, 0.2);
#     color: var(--jq-incorrect-color);
# }
#
#
# .DragDropOptions {
#     padding-top: 15px;
#     width: 100%;
#     display: block;
#     clear: both;
#     box-sizing: border-box;
# }
#
# .DragDropTitle {
#     font-size: 16px;
#     margin-bottom: 15px;
#     color: inherit;
#     text-align: left;
# }
#
# .DragDropOption {
#     /* Style to match MCButton */
#     background: var(--jq-mc-button-bg);
#     border: 1px solid var(--jq-mc-button-border);
#     border-radius: inherit;
#     color: #333333;
#     padding: 10px;
#     font-size: 16px;
#     cursor: grab;
#     text-align: center;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#
#     /* Drag-specific styles */
#     margin: 5px;
#     user-select: none;
#     transition: all 0.2s ease;
#     box-sizing: border-box;
#     min-width: 80px;
#     vertical-align: top;
# }
#
# .DragDropOption p {
#     color: inherit;
#     margin: 0;
# }
#
# .DragDropOption:hover {
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# }
#
# .DragDropOption.dragging {
#     opacity: 0.5;
#     cursor: grabbing;
# }
#
# .DragDropOption.selected {
#     background-color: var(--jq-correct-color, #0091cc);
#     color: var(--jq-text-color, white);
#     transform: translateY(-2px);
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.3);
# }
#
# /* Code styling within drag drop elements */
# .DragDropQn code {
#     background-color: lightgray;
#     color: black;
# }
#
# .DragDropOption co
